# %%
# %cd /content
# !rm -fr deep-learning-pa1
# !git clone -b experiment https://github.com/nicolasspaniol/deep-learning-pa1.git
# %cd deep-learning-pa1
# Out:
# /content
# Cloning into 'deep-learning-pa1'...
# remote: Enumerating objects: 329, done.
# remote: Counting objects: 100% (170/170), done.
# remote: Compressing objects: 100% (122/122), done.
# remote: Total 329 (delta 86), reused 85 (delta 41), pack-reused 159 (from 1)
# Receiving objects: 100% (329/329), 7.44 MiB | 11.67 MiB/s, done.
# Resolving deltas: 100% (148/148), done.
# /content/deep-learning-pa1

# %%
# !wget https://data.broadinstitute.org/bbbc/BBBC038/stage1_train.zip -P ./data
# !cd data && unzip -q stage1_train.zip -d stage1_train
# !rm ./data/stage1_train.zip
# Out:
# --2026-09-13 17:42:40--  https://data.broadinstitute.org/bbbc/BBBC038/stage1_train.zip
# Resolving data.broadinstitute.org (data.broadinstitute.org)... 69.173.68.137
# Connecting to data.broadinstitute.org (data.broadinstitute.org)|69.173.68.137|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 82923446 (79M) [application/zip]
# Saving to: ‘./data/stage1_train.zip’
#
# stage1_train.zip    100%[===================>]  79.08M  37.4MB/s    in 2.1s
#
# 2026-09-13 17:42:43 (37.4 MB/s) - ‘./data/stage1_train.zip’ saved [82923446/82923446]

# %%
from scripts.train_resunet_instances import main
main(10)
# Out:
# Loss 2.88:   0%|          | 0/1 [01:12<?, ?it/s]
